# %%
from google.colab import userdata
import json

# Get the Kaggle credentials from Colab's userdata
username = userdata.get("KAGGLE_USER")
key = userdata.get("KAGGLE_KEY")

# Echo the credentials into the kaggle.json file
# !mkdir -p ~/.kaggle
# !echo '{{"username":"{username}","key":"{key}"}}' > ~/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c io-t-sleep-stage-classification-version-2
# !unzip /content/io-t-sleep-stage-classification-version-2.zip && rm -rf /content/io-t-sleep-stage-classification-version-2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test_segment/test_segment/test003/test003_00692.csv
#   inflating: test_segment/test_segment/test003/test003_00693.csv
#   inflating: test_segment/test_segment/test003/test003_00694.csv
#   inflating: test_segment/test_segment/test003/test003_00695.csv
#   inflating: test_segment/test_segment/test003/test003_00696.csv
#   inflating: test_segment/test_segment/test003/test003_00697.csv
#   inflating: test_segment/test_segment/test003/test003_00698.csv
#   inflating: test_segment/test_segment/test003/test003_00699.csv
#   inflating: test_segment/test_segment/test003/test003_00700.csv
#   inflating: test_segment/test_segment/test004/test004_00000.csv
#   inflating: test_segment/test_segment/test004/test004_00001.csv
#   inflating: test_segment/test_segment/test004/test004_00002.csv
#   inflating: test_segment/test_segment/test004/test004_00003.csv
#   inflating: test_segment/test_segment/test004/test004_00004.csv
#   inflating: test_segment/test_segment/test004/test004_00005.csv
#   inflating: test_segment/test_segment/test004/test004_00006.csv
#   inflating: test_segment/test_segment/test004/test004_00007.csv
#   inflating: test_segment/test_segment/test004/test004_00008.csv
#   inflating: test_segment/test_segment/test004/test004_00009.csv
#   inflating: test_segment/test_segment/test004/test004_00010.csv
#   inflating: test_segment/test_segment/test004/test004_00011.csv
#   inflating: test_segment/test_segment/test004/test004_00012.csv
#   inflating: test_segment/test_segment/test004/test004_00013.csv
#   inflating: test_segment/test_segment/test004/test004_00014.csv
#   inflating: test_segment/test_segment/test004/test004_00015.csv
#   inflating: test_segment/test_segment/test004/test004_00016.csv
#   inflating: test_segment/test_segment/test004/test004_00017.csv
#   inflating: test_segment/test_segment/test004/test004_00018.csv
#   inflating: test_segment/test_segment/test004/test004_00019.csv
#   inflating: test_segment/test_segment/test004/test004_00020.csv
#   inflating: test_segment/test_segment/test004/test004_00021.csv
#   inflating: test_segment/test_segment/test004/test004_00022.csv
#   inflating: test_segment/test_segment/test004/test004_00023.csv
#   inflating: test_segment/test_segment/test004/test004_00024.csv
#   inflating: test_segment/test_segment/test004/test004_00025.csv
#   inflating: test_segment/test_segment/test004/test004_00026.csv
#   inflating: test_segment/test_segment/test004/test004_00027.csv
#   inflating: test_segment/test_segment/test004/test004_00028.csv
#   inflating: test_segment/test_segment/test004/test004_00029.csv
#   inflating: test_segment/test_segment/test004/test004_00030.csv
#   inflating: test_segment/test_segment/test004/test004_00031.csv
#   inflating: test_segment/test_segment/test004/test004_00032.csv
#   inflating: test_segment/test_segment/test004/test004_00033.csv
#   inflating: test_segment/test_segment/test004/test004_00034.csv
#   inflating: test_segment/test_segment/test004/test004_00035.csv
#   inflating: test_segment/test_segment/test004/test004_00036.csv
#   inflating: test_segment/test_segment/test004/test004_00037.csv
#   inflating: test_segment/test_segment/test004/test004_00038.csv
#   inflating: test_segment/test_segment/test004/test004_00039.csv
#   inflating: test_segment/test_segment/test004/test004_00040.csv
#   inflating: test_segment/test_segment/test004/test004_00041.csv
#   inflating: test_segment/test_segment/test004/test004_00042.csv
#   inflating: test_segment/test_segment/test004/test004_00043.csv
#   inflating: test_segment/test_segment/test004/test004_00044.csv
#   inflating: test_segment/test_segment/test004/test004_00045.csv
#   inflating: test_segment/test_segment/test004/test004_00046.csv
#   inflating: test_segment/test_segment/test004/test004_00047.csv
#   inflating: test_segment/test_segment/test004/test004_00048.csv
#   inflating: test_segment/test_segment/test004/test004_00049.csv
#   inflating: test_segment/test_segment/test004/test004_00050.csv
#   inflating: test_segment/test_segment/test004/test004_00051.csv
#   inflating: test_segment/test_segment/test004/test004_00052.csv
#   inflating: test_segment/test_segment/test004/test004_00053.csv
#   inflating: test_segment/test_segment/test004/test004_00054.csv
#   inflating: test_segment/test_segment/test004/test004_00055.csv
#   inflating: test_segment/test_segment/test004/test004_00056.csv
#   inflating: test_segment/test_segment/test004/test004_00057.csv
#   inflating: test_segment/test_segment/test004/test004_00058.csv
#   inflating: test_segment/test_segment/test004/test004_00059.csv
#   inflating: test_segment/test_segment/test004/test004_00060.csv
#   inflating: test_segment/test_segment/test004/test004_00061.csv
#   inflating: test_segment/test_segment/test004/test004_00062.csv
#   inflating: test_segment/test_segment/test004/test004_00063.csv
#   inflating: test_segment/test_segment/test004/test004_00064.csv
#   inflating: test_segment/test_segment/test004/test004_00065.csv
#   inflating: test_segment/test_segment/test004/test004_00066.csv
#   inflating: test_segment/test_segment/test004/test004_00067.csv
#   inflating: test_segment/test_segment/test004/test004_00068.csv
#   inflating: test_segment/test_segment/test004/test004_00069.csv
#   inflating: test_segment/test_segment/test004/test004_00070.csv
#   inflating: test_segment/test_segment/test004/test004_00071.csv
#   inflating: test_segment/test_segment/test004/test004_00072.csv
#   inflating: test_segment/test_segment/test004/test004_00073.csv
#   inflating: test_segment/test_segment/test004/test004_00074.csv
#   inflating: test_segment/test_segment/test004/test004_00075.csv
#   inflating: test_segment/test_segment/test004/test004_00076.csv
#   inflating: test_segment/test_segment/test004/test004_00077.csv
#   inflating: test_segment/test_segment/test004/test004_00078.csv
#   inflating: test_segment/test_segment/test004/test004_00079.csv
#   inflating: test_segment/test_segment/test004/test004_00080.csv
#   inflating: test_segment/test_segment/test004/test004_00081.csv
#   inflating: test_segment/test_segment/test004/test004_00082.csv
#   inflating: test_segment/test_segment/test004/test004_00083.csv
#   inflating: test_segment/test_segment/test004/test004_00084.csv
#   inflating: test_segment/test_segment/test004/test004_00085.csv
#   inflating: test_segment/test_segment/test004/test004_00086.csv
#   inflating: test_segment/test_segment/test004/test004_00087.csv
#   inflating: test_segment/test_segment/test004/test004_00088.csv
#   inflating: test_segment/test_segment/test004/test004_00089.csv
#   inflating: test_segment/test_segment/test004/test004_00090.csv
#   inflating: test_segment/test_segment/test004/test004_00091.csv
#   inflating: test_segment/test_segment/test004/test004_00092.csv
#   inflating: test_segment/test_segment/test004/test004_00093.csv
#   inflating: test_segment/test_segment/test004/test004_00094.csv
#   inflating: test_segment/test_segment/test004/test004_00095.csv
#   inflating: test_segment/test_segment/test004/test004_00096.csv
#   inflating: test_segment/test_segment/test004/test004_00097.csv
#   inflating: test_segment/test_segment/test004/test004_00098.csv
#   inflating: test_segment/test_segment/test004/test004_00099.csv
#   inflating: test_segment/test_segment/test004/test004_00100.csv
#   inflating: test_segment/test_segment/test004/test004_00101.csv
#   inflating: test_segment/test_segment/test004/test004_00102.csv
#   inflating: test_segment/test_segment/test004/test004_00103.csv
#   inflating: test_segment/test_segment/test004/test004_00104.csv
#   inflating: test_segment/test_segment/test004/test004_00105.csv
#   inflating: test_segment/test_segment/test004/test004_00106.csv
#   inflating: test_segment/test_segment/test004/test004_00107.csv
#   inflating: test_segment/test_segment/test004/test004_00108.csv
#   inflating: test_segment/test_segment/test004/test004_00109.csv
#   inflating: test_segment/test_segment/test004/test004_00110.csv
#   inflating: test_segment/test_segment/test004/test004_00111.csv
#   inflating: test_segment/test_segment/test004/test004_00112.csv
#   inflating: test_segment/test_segment/test004/test004_00113.csv
#   inflating: test_segment/test_segment/test004/test004_00114.csv
#   inflating: test_segment/test_segment/test004/test004_00115.csv
#   inflating: test_segment/test_segment/test004/test004_00116.csv
#   inflating: test_segment/test_segment/test004/test004_00117.csv
#   inflating: test_segment/test_segment/test004/test004_00118.csv
#   inflating: test_segment/test_segment/test004/test004_00119.csv
#   inflating: test_segment/test_segment/test004/test004_00120.csv
#   inflating: test_segment/test_segment/test004/test004_00121.csv
#   inflating: test_segment/test_segment/test004/test004_00122.csv
#   inflating: test_segment/test_segment/test004/test004_00123.csv
#   inflating: test_segment/test_segment/test004/test004_00124.csv
#   inflating: test_segment/test_segment/test004/test004_00125.csv
#   inflating: test_segment/test_segment/test004/test004_00126.csv
#   inflating: test_segment/test_segment/test004/test004_00127.csv
#   inflating: test_segment/test_segment/test004/test004_00128.csv
#   inflating: test_segment/test_segment/test004/test004_00129.csv
#   inflating: test_segment/test_segment/test004/test004_00130.csv
#   inflating: test_segment/test_segment/test004/test004_00131.csv
#   inflating: test_segment/test_segment/test004/test004_00132.csv
#   inflating: test_segment/test_segment/test004/test004_00133.csv
#   inflating: test_segment/test_segment/test004/test004_00134.csv
#   inflating: test_segment/test_segment/test004/test004_00135.csv
#   inflating: test_segment/test_segment/test004/test004_00136.csv
#   inflating: test_segment/test_segment/test004/test004_00137.csv
#   inflating: test_segment/test_segment/test004/test004_00138.csv
#   inflating: test_segment/test_segment/test004/test004_00139.csv
#   inflating: test_segment/test_segment/test004/test004_00140.csv
#   inflating: test_segment/test_segment/test004/test004_00141.csv
#   inflating: test_segment/test_segment/test004/test004_00142.csv
#   inflating: test_segment/test_segment/test004/test004_00143.csv
#   inflating: test_segment/test_segment/test004/test004_00144.csv
#   inflating: test_segment/test_segment/test004/test004_00145.csv
#   inflating: test_segment/test_segment/test004/test004_00146.csv
#   inflating: test_segment/test_segment/test004/test004_00147.csv
#   inflating: test_segment/test_segment/test004/test004_00148.csv
#   inflating: test_segment/test_segment/test004/test004_00149.csv
#   inflating: test_segment/test_segment/test004/test004_00150.csv
#   inflating: test_segment/test_segment/test004/test004_00151.csv
#   inflating: test_segment/test_segment/test004/test004_00152.csv
#   inflating: test_segment/test_segment/test004/test004_00153.csv
#   inflating: test_segment/test_segment/test004/test004_00154.csv
#   inflating: test_segment/test_segment/test004/test004_00155.csv
#   inflating: test_segment/test_segment/test004/test004_00156.csv
#   inflating: test_segment/test_segment/test004/test004_00157.csv
#   inflating: test_segment/test_segment/test004/test004_00158.csv
#   inflating: test_segment/test_segment/test004/test004_00159.csv
#   inflating: test_segment/test_segment/test004/test004_00160.csv
#   inflating: test_segment/test_segment/test004/test004_00161.csv
#   inflating: test_segment/test_segment/test004/test004_00162.csv
#   inflating: test_segment/test_segment/test004/test004_00163.csv
#   inflating: test_segment/test_segment/test004/test004_00164.csv
#   inflating: test_segment/test_segment/test004/test004_00165.csv
#   inflating: test_segment/test_segment/test004/test004_00166.csv
#   inflating: test_segment/test_segment/test004/test004_00167.csv
#   inflating: test_segment/test_segment/test004/test004_00168.csv
#   inflating: test_segment/test_segment/test004/test004_00169.csv
#   inflating: test_segment/test_segment/test004/test004_00170.csv
#   inflating: test_segment/test_segment/test004/test004_00171.csv
#   inflating: test_segment/test_segment/test004/test004_00172.csv
#   inflating: test_segment/test_segment/test004/test004_00173.csv
#   inflating: test_segment/test_segment/test004/test004_00174.csv
#   inflating: test_segment/test_segment/test004/test004_00175.csv
#   inflating: test_segment/test_segment/test004/test004_00176.csv
#   inflating: test_segment/test_segment/test004/test004_00177.csv
#   inflating: test_segment/test_segment/test004/test004_00178.csv
#   inflating: test_segment/test_segment/test004/test004_00179.csv
#   inflating: test_segment/test_segment/test004/test004_00180.csv
#   inflating: test_segment/test_segment/test004/test004_00181.csv
#   inflating: test_segment/test_segment/test004/test004_00182.csv
#   inflating: test_segment/test_segment/test004/test004_00183.csv
#   inflating: test_segment/test_segment/test004/test004_00184.csv
#   inflating: test_segment/test_segment/test004/test004_00185.csv
#   inflating: test_segment/test_segment/test004/test004_00186.csv
#   inflating: test_segment/test_segment/test004/test004_00187.csv
#   inflating: test_segment/test_segment/test004/test004_00188.csv
#   inflating: test_segment/test_segment/test004/test004_00189.csv
#   inflating: test_segment/test_segment/test004/test004_00190.csv
#   inflating: test_segment/test_segment/test004/test004_00191.csv
#   inflating: test_segment/test_segment/test004/test004_00192.csv
#   inflating: test_segment/test_segment/test004/test004_00193.csv
#   inflating: test_segment/test_segment/test004/test004_00194.csv
#   inflating: test_segment/test_segment/test004/test004_00195.csv
#   inflating: test_segment/test_segment/test004/test004_00196.csv
#   inflating: test_segment/test_segment/test004/test004_00197.csv
#   inflating: test_segment/test_segment/test004/test004_00198.csv
#   inflating: test_segment/test_segment/test004/test004_00199.csv
#   inflating: test_segment/test_segment/test004/test004_00200.csv
#   inflating: test_segment/test_segment/test004/test004_00201.csv
#   inflating: test_segment/test_segment/test004/test004_00202.csv
#   inflating: test_segment/test_segment/test004/test004_00203.csv
#   inflating: test_segment/test_segment/test004/test004_00204.csv
#   inflating: test_segment/test_segment/test004/test004_00205.csv
#   inflating: test_segment/test_segment/test004/test004_00206.csv
#   inflating: test_segment/test_segment/test004/test004_00207.csv
#   inflating: test_segment/test_segment/test004/test004_00208.csv
#   inflating: test_segment/test_segment/test004/test004_00209.csv
#   inflating: test_segment/test_segment/test004/test004_00210.csv
#   inflating: test_segment/test_segment/test004/test004_00211.csv
#   inflating: test_segment/test_segment/test004/test004_00212.csv
#   inflating: test_segment/test_segment/test004/test004_00213.csv
#   inflating: test_segment/test_segment/test004/test004_00214.csv
#   inflating: test_segment/test_segment/test004/test004_00215.csv
#   inflating: test_segment/test_segment/test004/test004_00216.csv
#   inflating: test_segment/test_segment/test004/test004_00217.csv
#   inflating: test_segment/test_segment/test004/test004_00218.csv
#   inflating: test_segment/test_segment/test004/test004_00219.csv
#   inflating: test_segment/test_segment/test004/test004_00220.csv
#   inflating: test_segment/test_segment/test004/test004_00221.csv
#   inflating: test_segment/test_segment/test004/test004_00222.csv
#   inflating: test_segment/test_segment/test004/test004_00223.csv
#   inflating: test_segment/test_segment/test004/test004_00224.csv
#   inflating: test_segment/test_segment/test004/test004_00225.csv
#   inflating: test_segment/test_segment/test004/test004_00226.csv
#   inflating: test_segment/test_segment/test004/test004_00227.csv
#   inflating: test_segment/test_segment/test004/test004_00228.csv
#   inflating: test_segment/test_segment/test004/test004_00229.csv
#   inflating: test_segment/test_segment/test004/test004_00230.csv
#   inflating: test_segment/test_segment/test004/test004_00231.csv
#   inflating: test_segment/test_segment/test004/test004_00232.csv
#   inflating: test_segment/test_segment/test004/test004_00233.csv
#   inflating: test_segment/test_segment/test004/test004_00234.csv
#   inflating: test_segment/test_segment/test004/test004_00235.csv
#   inflating: test_segment/test_segment/test004/test004_00236.csv
#   inflating: test_segment/test_segment/test004/test004_00237.csv
#   inflating: test_segment/test_segment/test004/test004_00238.csv
#   inflating: test_segment/test_segment/test004/test004_00239.csv
#   inflating: test_segment/test_segment/test004/test004_00240.csv
#   inflating: test_segment/test_segment/test004/test004_00241.csv
#   inflating: test_segment/test_segment/test004/test004_00242.csv
#   inflating: test_segment/test_segment/test004/test004_00243.csv
#   inflating: test_segment/test_segment/test004/test004_00244.csv
#   inflating: test_segment/test_segment/test004/test004_00245.csv
#   inflating: test_segment/test_segment/test004/test004_00246.csv
#   inflating: test_segment/test_segment/test004/test004_00247.csv
#   inflating: test_segment/test_segment/test004/test004_00248.csv
#   inflating: test_segment/test_segment/test004/test004_00249.csv
#   inflating: test_segment/test_segment/test004/test004_00250.csv
#   inflating: test_segment/test_segment/test004/test004_00251.csv
#   inflating: test_segment/test_segment/test004/test004_00252.csv
#   inflating: test_segment/test_segment/test004/test004_00253.csv
#   inflating: test_segment/test_segment/test004/test004_00254.csv
#   inflating: test_segment/test_segment/test004/test004_00255.csv
#   inflating: test_segment/test_segment/test004/test004_00256.csv
#   inflating: test_segment/test_segment/test004/test004_00257.csv
#   inflating: test_segment/test_segment/test004/test004_00258.csv
#   inflating: test_segment/test_segment/test004/test004_00259.csv
#   inflating: test_segment/test_segment/test004/test004_00260.csv
#   inflating: test_segment/test_segment/test004/test004_00261.csv
#   inflating: test_segment/test_segment/test004/test004_00262.csv
#   inflating: test_segment/test_segment/test004/test004_00263.csv
#   inflating: test_segment/test_segment/test004/test004_00264.csv
#   inflating: test_segment/test_segment/test004/test004_00265.csv
#   inflating: test_segment/test_segment/test004/test004_00266.csv
#   inflating: test_segment/test_segment/test004/test004_00267.csv
#   inflating: test_segment/test_segment/test004/test004_00268.csv
#   inflating: test_segment/test_segment/test004/test004_00269.csv
#   inflating: test_segment/test_segment/test004/test004_00270.csv
#   inflating: test_segment/test_segment/test004/test004_00271.csv
#   inflating: test_segment/test_segment/test004/test004_00272.csv
#   inflating: test_segment/test_segment/test004/test004_00273.csv
#   inflating: test_segment/test_segment/test004/test004_00274.csv
#   inflating: test_segment/test_segment/test004/test004_00275.csv
#   inflating: test_segment/test_segment/test004/test004_00276.csv
#   inflating: test_segment/test_segment/test004/test004_00277.csv
#   inflating: test_segment/test_segment/test004/test004_00278.csv
#   inflating: test_segment/test_segment/test004/test004_00279.csv
#   inflating: test_segment/test_segment/test004/test004_00280.csv
#   inflating: test_segment/test_segment/test004/test004_00281.csv
#   inflating: test_segment/test_segment/test004/test004_00282.csv
#   inflating: test_segment/test_segment/test004/test004_00283.csv
#   inflating: test_segment/test_segment/test004/test004_00284.csv
#   inflating: test_segment/test_segment/test004/test004_00285.csv
#   inflating: test_segment/test_segment/test004/test004_00286.csv
#   inflating: test_segment/test_segment/test004/test004_00287.csv
#   inflating: test_segment/test_segment/test004/test004_00288.csv
#   inflating: test_segment/test_segment/test004/test004_00289.csv
#   inflating: test_segment/test_segment/test004/test004_00290.csv
#   inflating: test_segment/test_segment/test004/test004_00291.csv
#   inflating: test_segment/test_segment/test004/test004_00292.csv
#   inflating: test_segment/test_segment/test004/test004_00293.csv
#   inflating: test_segment/test_segment/test004/test004_00294.csv
#   inflating: test_segment/test_segment/test004/test004_00295.csv
#   inflating: test_segment/test_segment/test004/test004_00296.csv
#   inflating: test_segment/test_segment/test004/test004_00297.csv
#   inflating: test_segment/test_segment/test004/test004_00298.csv
#   inflating: test_segment/test_segment/test004/test004_00299.csv
#   inflating: test_segment/test_segment/test004/test004_00300.csv
#   inflating: test_segment/test_segment/test004/test004_00301.csv
#   inflating: test_segment/test_segment/test004/test004_00302.csv
#   inflating: test_segment/test_segment/test004/test004_00303.csv
#   inflating: test_segment/test_segment/test004/test004_00304.csv
#   inflating: test_segment/test_segment/test004/test004_00305.csv
#   inflating: test_segment/test_segment/test004/test004_00306.csv
#   inflating: test_segment/test_segment/test004/test004_00307.csv
#   inflating: test_segment/test_segment/test004/test004_00308.csv
#   inflating: test_segment/test_segment/test004/test004_00309.csv
#   inflating: test_segment/test_segment/test004/test004_00310.csv
#   inflating: test_segment/test_segment/test004/test004_00311.csv
#   inflating: test_segment/test_segment/test004/test004_00312.csv
#   inflating: test_segment/test_segment/test004/test004_00313.csv
#   inflating: test_segment/test_segment/test004/test004_00314.csv
#   inflating: test_segment/test_segment/test004/test004_00315.csv
#   inflating: test_segment/test_segment/test004/test004_00316.csv
#   inflating: test_segment/test_segment/test004/test004_00317.csv
#   inflating: test_segment/test_segment/test004/test004_00318.csv
#   inflating: test_segment/test_segment/test004/test004_00319.csv
#   inflating: test_segment/test_segment/test004/test004_00320.csv
#   inflating: test_segment/test_segment/test004/test004_00321.csv
#   inflating: test_segment/test_segment/test004/test004_00322.csv
#   inflating: test_segment/test_segment/test004/test004_00323.csv
#   inflating: test_segment/test_segment/test004/test004_00324.csv
#   inflating: test_segment/test_segment/test004/test004_00325.csv
#   inflating: test_segment/test_segment/test004/test004_00326.csv
#   inflating: test_segment/test_segment/test004/test004_00327.csv
#   inflating: test_segment/test_segment/test004/test004_00328.csv
#   inflating: test_segment/test_segment/test004/test004_00329.csv
#   inflating: test_segment/test_segment/test004/test004_00330.csv
#   inflating: test_segment/test_segment/test004/test004_00331.csv
#   inflating: test_segment/test_segment/test004/test004_00332.csv
#   inflating: test_segment/test_segment/test004/test004_00333.csv
#   inflating: test_segment/test_segment/test004/test004_00334.csv
#   inflating: test_segment/test_segment/test004/test004_00335.csv
#   inflating: test_segment/test_segment/test004/test004_00336.csv
#   inflating: test_segment/test_segment/test004/test004_00337.csv
#   inflating: test_segment/test_segment/test004/test004_00338.csv
#   inflating: test_segment/test_segment/test004/test004_00339.csv
#   inflating: test_segment/test_segment/test004/test004_00340.csv
#   inflating: test_segment/test_segment/test004/test004_00341.csv
#   inflating: test_segment/test_segment/test004/test004_00342.csv
#   inflating: test_segment/test_segment/test004/test004_00343.csv
#   inflating: test_segment/test_segment/test004/test004_00344.csv
#   inflating: test_segment/test_segment/test004/test004_00345.csv
#   inflating: test_segment/test_segment/test004/test004_00346.csv
#   inflating: test_segment/test_segment/test004/test004_00347.csv
#   inflating: test_segment/test_segment/test004/test004_00348.csv
#   inflating: test_segment/test_segment/test004/test004_00349.csv
#   inflating: test_segment/test_segment/test004/test004_00350.csv
#   inflating: test_segment/test_segment/test004/test004_00351.csv
#   inflating: test_segment/test_segment/test004/test004_00352.csv
#   inflating: test_segment/test_segment/test004/test004_00353.csv
#   inflating: test_segment/test_segment/test004/test004_00354.csv
#   inflating: test_segment/test_segment/test004/test004_00355.csv
#   inflating: test_segment/test_segment/test004/test004_00356.csv
#   inflating: test_segment/test_segment/test004/test004_00357.csv
#   inflating: test_segment/test_segment/test004/test004_00358.csv
#   inflating: test_segment/test_segment/test004/test004_00359.csv
#   inflating: test_segment/test_segment/test004/test004_00360.csv
#   inflating: test_segment/test_segment/test004/test004_00361.csv
#   inflating: test_segment/test_segment/test004/test004_00362.csv
#   inflating: test_segment/test_segment/test004/test004_00363.csv
#   inflating: test_segment/test_segment/test004/test004_00364.csv
#   inflating: test_segment/test_segment/test004/test004_00365.csv
#   inflating: test_segment/test_segment/test004/test004_00366.csv
#   inflating: test_segment/test_segment/test004/test004_00367.csv
#   inflating: test_segment/test_segment/test004/test004_00368.csv
#   inflating: test_segment/test_segment/test004/test004_00369.csv
#   inflating: test_segment/test_segment/test004/test004_00370.csv
#   inflating: test_segment/test_segment/test004/test004_00371.csv
#   inflating: test_segment/test_segment/test004/test004_00372.csv
#   inflating: test_segment/test_segment/test004/test004_00373.csv
#   inflating: test_segment/test_segment/test004/test004_00374.csv
#   inflating: test_segment/test_segment/test004/test004_00375.csv
#   inflating: test_segment/test_segment/test004/test004_00376.csv
#   inflating: test_segment/test_segment/test004/test004_00377.csv
#   inflating: test_segment/test_segment/test004/test004_00378.csv
#   inflating: test_segment/test_segment/test004/test004_00379.csv
#   inflating: test_segment/test_segment/test004/test004_00380.csv
#   inflating: test_segment/test_segment/test004/test004_00381.csv
#   inflating: test_segment/test_segment/test004/test004_00382.csv
#   inflating: test_segment/test_segment/test004/test004_00383.csv
#   inflating: test_segment/test_segment/test004/test004_00384.csv
#   inflating: test_segment/test_segment/test004/test004_00385.csv
#   inflating: test_segment/test_segment/test004/test004_00386.csv
#   inflating: test_segment/test_segment/test004/test004_00387.csv
#   inflating: test_segment/test_segment/test004/test004_00388.csv
#   inflating: test_segment/test_segment/test004/test004_00389.csv
#   inflating: test_segment/test_segment/test004/test004_00390.csv
#   inflating: test_segment/test_segment/test004/test004_00391.csv
#   inflating: test_segment/test_segment/test004/test004_00392.csv
#   inflating: test_segment/test_segment/test004/test004_00393.csv
#   inflating: test_segment/test_segment/test004/test004_00394.csv
#   inflating: test_segment/test_segment/test004/test004_00395.csv
#   inflating: test_segment/test_segment/test004/test004_00396.csv
#   inflating: test_segment/test_segment/test004/test004_00397.csv
#   inflating: test_segment/test_segment/test004/test004_00398.csv
#   inflating: test_segment/test_segment/test004/test004_00399.csv
#   inflating: test_segment/test_segment/test004/test004_00400.csv
#   inflating: test_segment/test_segment/test004/test004_00401.csv
#   inflating: test_segment/test_segment/test004/test004_00402.csv
#   inflating: test_segment/test_segment/test004/test004_00403.csv
#   inflating: test_segment/test_segment/test004/test004_00404.csv
#   inflating: test_segment/test_segment/test004/test004_00405.csv
#   inflating: test_segment/test_segment/test004/test004_00406.csv
#   inflating: test_segment/test_segment/test004/test004_00407.csv
#   inflating: test_segment/test_segment/test004/test004_00408.csv
#   inflating: test_segment/test_segment/test004/test004_00409.csv
#   inflating: test_segment/test_segment/test004/test004_00410.csv
#   inflating: test_segment/test_segment/test004/test004_00411.csv
#   inflating: test_segment/test_segment/test004/test004_00412.csv
#   inflating: test_segment/test_segment/test004/test004_00413.csv
#   inflating: test_segment/test_segment/test004/test004_00414.csv
#   inflating: test_segment/test_segment/test004/test004_00415.csv
#   inflating: test_segment/test_segment/test004/test004_00416.csv
#   inflating: test_segment/test_segment/test004/test004_00417.csv
#   inflating: test_segment/test_segment/test004/test004_00418.csv
#   inflating: test_segment/test_segment/test004/test004_00419.csv
#   inflating: test_segment/test_segment/test004/test004_00420.csv
#   inflating: test_segment/test_segment/test004/test004_00421.csv
#   inflating: test_segment/test_segment/test004/test004_00422.csv
#   inflating: test_segment/test_segment/test004/test004_00423.csv
#   inflating: test_segment/test_segment/test004/test004_00424.csv
#   inflating: test_segment/test_segment/test004/test004_00425.csv
#   inflating: test_segment/test_segment/test004/test004_00426.csv
#   inflating: test_segment/test_segment/test004/test004_00427.csv
#   inflating: test_segment/test_segment/test004/test004_00428.csv
#   inflating: test_segment/test_segment/test004/test004_00429.csv
#   inflating: test_segment/test_segment/test004/test004_00430.csv
#   inflating: test_segment/test_segment/test004/test004_00431.csv
#   inflating: test_segment/test_segment/test004/test004_00432.csv
#   inflating: test_segment/test_segment/test004/test004_00433.csv
#   inflating: test_segment/test_segment/test004/test004_00434.csv
#   inflating: test_segment/test_segment/test004/test004_00435.csv
#   inflating: test_segment/test_segment/test004/test004_00436.csv
#   inflating: test_segment/test_segment/test004/test004_00437.csv
#   inflating: test_segment/test_segment/test004/test004_00438.csv
#   inflating: test_segment/test_segment/test004/test004_00439.csv
#   inflating: test_segment/test_segment/test004/test004_00440.csv
#   inflating: test_segment/test_segment/test004/test004_00441.csv
#   inflating: test_segment/test_segment/test004/test004_00442.csv
#   inflating: test_segment/test_segment/test004/test004_00443.csv
#   inflating: test_segment/test_segment/test004/test004_00444.csv
#   inflating: test_segment/test_segment/test004/test004_00445.csv
#   inflating: test_segment/test_segment/test004/test004_00446.csv
#   inflating: test_segment/test_segment/test004/test004_00447.csv
#   inflating: test_segment/test_segment/test004/test004_00448.csv
#   inflating: test_segment/test_segment/test004/test004_00449.csv
#   inflating: test_segment/test_segment/test004/test004_00450.csv
#   inflating: test_segment/test_segment/test004/test004_00451.csv
#   inflating: test_segment/test_segment/test004/test004_00452.csv
#   inflating: test_segment/test_segment/test004/test004_00453.csv
#   inflating: test_segment/test_segment/test004/test004_00454.csv
#   inflating: test_segment/test_segment/test004/test004_00455.csv
#   inflating: test_segment/test_segment/test004/test004_00456.csv
#   inflating: test_segment/test_segment/test004/test004_00457.csv
#   inflating: test_segment/test_segment/test004/test004_00458.csv
#   inflating: test_segment/test_segment/test004/test004_00459.csv
#   inflating: test_segment/test_segment/test004/test004_00460.csv
#   inflating: test_segment/test_segment/test004/test004_00461.csv
#   inflating: test_segment/test_segment/test004/test004_00462.csv
#   inflating: test_segment/test_segment/test004/test004_00463.csv
#   inflating: test_segment/test_segment/test004/test004_00464.csv
#   inflating: test_segment/test_segment/test004/test004_00465.csv
#   inflating: test_segment/test_segment/test004/test004_00466.csv
#   inflating: test_segment/test_segment/test004/test004_00467.csv
#   inflating: test_segment/test_segment/test004/test004_00468.csv
#   inflating: test_segment/test_segment/test004/test004_00469.csv
#   inflating: test_segment/test_segment/test004/test004_00470.csv
#   inflating: test_segment/test_segment/test004/test004_00471.csv
#   inflating: test_segment/test_segment/test004/test004_00472.csv
#   inflating: test_segment/test_segment/test004/test004_00473.csv
#   inflating: test_segment/test_segment/test004/test004_00474.csv
#   inflating: test_segment/test_segment/test004/test004_00475.csv
#   inflating: test_segment/test_segment/test004/test004_00476.csv
#   inflating: test_segment/test_segment/test004/test004_00477.csv
#   inflating: test_segment/test_segment/test004/test004_00478.csv
#   inflating: test_segment/test_segment/test004/test004_00479.csv
#   inflating: test_segment/test_segment/test004/test004_00480.csv
#   inflating: test_segment/test_segment/test004/test004_00481.csv
#   inflating: test_segment/test_segment/test004/test004_00482.csv
#   inflating: test_segment/test_segment/test004/test004_00483.csv
#   inflating: test_segment/test_segment/test004/test004_00484.csv
#   inflating: test_segment/test_segment/test004/test004_00485.csv
#   inflating: test_segment/test_segment/test004/test004_00486.csv
#   inflating: test_segment/test_segment/test004/test004_00487.csv
#   inflating: test_segment/test_segment/test004/test004_00488.csv
#   inflating: test_segment/test_segment/test004/test004_00489.csv
#   inflating: test_segment/test_segment/test004/test004_00490.csv
#   inflating: test_segment/test_segment/test004/test004_00491.csv
#   inflating: test_segment/test_segment/test004/test004_00492.csv
#   inflating: test_segment/test_segment/test004/test004_00493.csv
#   inflating: test_segment/test_segment/test004/test004_00494.csv
#   inflating: test_segment/test_segment/test004/test004_00495.csv
#   inflating: test_segment/test_segment/test004/test004_00496.csv
#   inflating: test_segment/test_segment/test004/test004_00497.csv
#   inflating: test_segment/test_segment/test004/test004_00498.csv
#   inflating: test_segment/test_segment/test004/test004_00499.csv
#   inflating: test_segment/test_segment/test004/test004_00500.csv
#   inflating: test_segment/test_segment/test004/test004_00501.csv
#   inflating: test_segment/test_segment/test004/test004_00502.csv
#   inflating: test_segment/test_segment/test004/test004_00503.csv
#   inflating: test_segment/test_segment/test004/test004_00504.csv
#   inflating: test_segment/test_segment/test004/test004_00505.csv
#   inflating: test_segment/test_segment/test004/test004_00506.csv
#   inflating: test_segment/test_segment/test004/test004_00507.csv
#   inflating: test_segment/test_segment/test004/test004_00508.csv
#   inflating: test_segment/test_segment/test004/test004_00509.csv
#   inflating: test_segment/test_segment/test004/test004_00510.csv
#   inflating: test_segment/test_segment/test004/test004_00511.csv
#   inflating: test_segment/test_segment/test004/test004_00512.csv
#   inflating: test_segment/test_segment/test004/test004_00513.csv
#   inflating: test_segment/test_segment/test004/test004_00514.csv
#   inflating: test_segment/test_segment/test004/test004_00515.csv
#   inflating: test_segment/test_segment/test004/test004_00516.csv
#   inflating: test_segment/test_segment/test004/test004_00517.csv
#   inflating: test_segment/test_segment/test004/test004_00518.csv
#   inflating: test_segment/test_segment/test004/test004_00519.csv
#   inflating: test_segment/test_segment/test004/test004_00520.csv
#   inflating: test_segment/test_segment/test004/test004_00521.csv
#   inflating: test_segment/test_segment/test004/test004_00522.csv
#   inflating: test_segment/test_segment/test004/test004_00523.csv
#   inflating: test_segment/test_segment/test004/test004_00524.csv
#   inflating: test_segment/test_segment/test004/test004_00525.csv
#   inflating: test_segment/test_segment/test004/test004_00526.csv
#   inflating: test_segment/test_segment/test004/test004_00527.csv
#   inflating: test_segment/test_segment/test004/test004_00528.csv
#   inflating: test_segment/test_segment/test004/test004_00529.csv
#   inflating: test_segment/test_segment/test004/test004_00530.csv
#   inflating: test_segment/test_segment/test004/test004_00531.csv
#   inflating: test_segment/test_segment/test004/test004_00532.csv
#   inflating: test_segment/test_segment/test004/test004_00533.csv
#   inflating: test_segment/test_segment/test004/test004_00534.csv
#   inflating: test_segment/test_segment/test004/test004_00535.csv
#   inflating: test_segment/test_segment/test004/test004_00536.csv
#   inflating: test_segment/test_segment/test004/test004_00537.csv
#   inflating: test_segment/test_segment/test004/test004_00538.csv
#   inflating: test_segment/test_segment/test004/test004_00539.csv
#   inflating: test_segment/test_segment/test004/test004_00540.csv
#   inflating: test_segment/test_segment/test004/test004_00541.csv
#   inflating: test_segment/test_segment/test004/test004_00542.csv
#   inflating: test_segment/test_segment/test004/test004_00543.csv
#   inflating: test_segment/test_segment/test004/test004_00544.csv
#   inflating: test_segment/test_segment/test004/test004_00545.csv
#   inflating: test_segment/test_segment/test004/test004_00546.csv
#   inflating: test_segment/test_segment/test004/test004_00547.csv
#   inflating: test_segment/test_segment/test004/test004_00548.csv
#   inflating: test_segment/test_segment/test004/test004_00549.csv
#   inflating: test_segment/test_segment/test004/test004_00550.csv
#   inflating: test_segment/test_segment/test004/test004_00551.csv
#   inflating: test_segment/test_segment/test004/test004_00552.csv
#   inflating: test_segment/test_segment/test004/test004_00553.csv
#   inflating: test_segment/test_segment/test004/test004_00554.csv
#   inflating: test_segment/test_segment/test004/test004_00555.csv
#   inflating: test_segment/test_segment/test004/test004_00556.csv
#   inflating: test_segment/test_segment/test004/test004_00557.csv
#   inflating: test_segment/test_segment/test004/test004_00558.csv
#   inflating: test_segment/test_segment/test004/test004_00559.csv
#   inflating: test_segment/test_segment/test004/test004_00560.csv
#   inflating: test_segment/test_segment/test004/test004_00561.csv
#   inflating: test_segment/test_segment/test004/test004_00562.csv
#   inflating: test_segment/test_segment/test004/test004_00563.csv
#   inflating: test_segment/test_segment/test004/test004_00564.csv
#   inflating: test_segment/test_segment/test004/test004_00565.csv
#   inflating: test_segment/test_segment/test004/test004_00566.csv
#   inflating: test_segment/test_segment/test004/test004_00567.csv
#   inflating: test_segment/test_segment/test004/test004_00568.csv
#   inflating: test_segment/test_segment/test004/test004_00569.csv
#   inflating: test_segment/test_segment/test004/test004_00570.csv
#   inflating: test_segment/test_segment/test004/test004_00571.csv
#   inflating: test_segment/test_segment/test004/test004_00572.csv
#   inflating: test_segment/test_segment/test004/test004_00573.csv
#   inflating: test_segment/test_segment/test004/test004_00574.csv
#   inflating: test_segment/test_segment/test004/test004_00575.csv
#   inflating: test_segment/test_segment/test004/test004_00576.csv
#   inflating: test_segment/test_segment/test004/test004_00577.csv
#   inflating: test_segment/test_segment/test004/test004_00578.csv
#   inflating: test_segment/test_segment/test004/test004_00579.csv
#   inflating: test_segment/test_segment/test004/test004_00580.csv
#   inflating: test_segment/test_segment/test004/test004_00581.csv
#   inflating: test_segment/test_segment/test004/test004_00582.csv
#   inflating: test_segment/test_segment/test004/test004_00583.csv
#   inflating: test_segment/test_segment/test004/test004_00584.csv
#   inflating: test_segment/test_segment/test004/test004_00585.csv
#   inflating: test_segment/test_segment/test004/test004_00586.csv
#   inflating: test_segment/test_segment/test004/test004_00587.csv
#   inflating: test_segment/test_segment/test004/test004_00588.csv
#   inflating: test_segment/test_segment/test004/test004_00589.csv
#   inflating: test_segment/test_segment/test004/test004_00590.csv
#   inflating: test_segment/test_segment/test004/test004_00591.csv
#   inflating: test_segment/test_segment/test004/test004_00592.csv
#   inflating: test_segment/test_segment/test004/test004_00593.csv
#   inflating: test_segment/test_segment/test004/test004_00594.csv
#   inflating: test_segment/test_segment/test004/test004_00595.csv
#   inflating: test_segment/test_segment/test004/test004_00596.csv
#   inflating: test_segment/test_segment/test004/test004_00597.csv
#   inflating: test_segment/test_segment/test004/test004_00598.csv
#   inflating: test_segment/test_segment/test004/test004_00599.csv
#   inflating: test_segment/test_segment/test004/test004_00600.csv
#   inflating: test_segment/test_segment/test004/test004_00601.csv
#   inflating: test_segment/test_segment/test004/test004_00602.csv
#   inflating: test_segment/test_segment/test004/test004_00603.csv
#   inflating: test_segment/test_segment/test004/test004_00604.csv
#   inflating: test_segment/test_segment/test004/test004_00605.csv
#   inflating: test_segment/test_segment/test004/test004_00606.csv
#   inflating: test_segment/test_segment/test004/test004_00607.csv
#   inflating: test_segment/test_segment/test004/test004_00608.csv
#   inflating: test_segment/test_segment/test004/test004_00609.csv
#   inflating: test_segment/test_segment/test004/test004_00610.csv
#   inflating: test_segment/test_segment/test004/test004_00611.csv
#   inflating: test_segment/test_segment/test004/test004_00612.csv
#   inflating: test_segment/test_segment/test004/test004_00613.csv
#   inflating: test_segment/test_segment/test004/test004_00614.csv
#   inflating: test_segment/test_segment/test004/test004_00615.csv
#   inflating: test_segment/test_segment/test004/test004_00616.csv
#   inflating: test_segment/test_segment/test004/test004_00617.csv
#   inflating: test_segment/test_segment/test004/test004_00618.csv
#   inflating: test_segment/test_segment/test004/test004_00619.csv
#   inflating: test_segment/test_segment/test004/test004_00620.csv
#   inflating: test_segment/test_segment/test004/test004_00621.csv
#   inflating: test_segment/test_segment/test004/test004_00622.csv
#   inflating: test_segment/test_segment/test004/test004_00623.csv
#   inflating: test_segment/test_segment/test004/test004_00624.csv
#   inflating: test_segment/test_segment/test004/test004_00625.csv
#   inflating: test_segment/test_segment/test004/test004_00626.csv
#   inflating: test_segment/test_segment/test004/test004_00627.csv
#   inflating: test_segment/test_segment/test004/test004_00628.csv
#   inflating: test_segment/test_segment/test004/test004_00629.csv
#   inflating: test_segment/test_segment/test004/test004_00630.csv
#   inflating: test_segment/test_segment/test004/test004_00631.csv
#   inflating: test_segment/test_segment/test004/test004_00632.csv
#   inflating: test_segment/test_segment/test004/test004_00633.csv
#   inflating: test_segment/test_segment/test004/test004_00634.csv
#   inflating: test_segment/test_segment/test004/test004_00635.csv
#   inflating: test_segment/test_segment/test004/test004_00636.csv
#   inflating: test_segment/test_segment/test004/test004_00637.csv
#   inflating: test_segment/test_segment/test004/test004_00638.csv
#   inflating: test_segment/test_segment/test004/test004_00639.csv
#   inflating: test_segment/test_segment/test004/test004_00640.csv
#   inflating: test_segment/test_segment/test004/test004_00641.csv
#   inflating: test_segment/test_segment/test004/test004_00642.csv
#   inflating: test_segment/test_segment/test004/test004_00643.csv
#   inflating: test_segment/test_segment/test004/test004_00644.csv
#   inflating: test_segment/test_segment/test004/test004_00645.csv
#   inflating: test_segment/test_segment/test004/test004_00646.csv
#   inflating: test_segment/test_segment/test004/test004_00647.csv
#   inflating: test_segment/test_segment/test004/test004_00648.csv
#   inflating: test_segment/test_segment/test004/test004_00649.csv
#   inflating: test_segment/test_segment/test004/test004_00650.csv
#   inflating: test_segment/test_segment/test004/test004_00651.csv
#   inflating: test_segment/test_segment/test004/test004_00652.csv
#   inflating: test_segment/test_segment/test004/test004_00653.csv
#   inflating: test_segment/test_segment/test004/test004_00654.csv
#   inflating: test_segment/test_segment/test004/test004_00655.csv
#   inflating: test_segment/test_segment/test004/test004_00656.csv
#   inflating: test_segment/test_segment/test004/test004_00657.csv
#   inflating: test_segment/test_segment/test004/test004_00658.csv
#   inflating: test_segment/test_segment/test004/test004_00659.csv
#   inflating: test_segment/test_segment/test004/test004_00660.csv
#   inflating: test_segment/test_segment/test004/test004_00661.csv
#   inflating: test_segment/test_segment/test004/test004_00662.csv
#   inflating: test_segment/test_segment/test004/test004_00663.csv
#   inflating: test_segment/test_segment/test004/test004_00664.csv
#   inflating: test_segment/test_segment/test004/test004_00665.csv
#   inflating: test_segment/test_segment/test004/test004_00666.csv
#   inflating: test_segment/test_segment/test004/test004_00667.csv
#   inflating: test_segment/test_segment/test004/test004_00668.csv
#   inflating: test_segment/test_segment/test004/test004_00669.csv
#   inflating: test_segment/test_segment/test004/test004_00670.csv
#   inflating: test_segment/test_segment/test004/test004_00671.csv
#   inflating: test_segment/test_segment/test004/test004_00672.csv
#   inflating: test_segment/test_segment/test004/test004_00673.csv
#   inflating: test_segment/test_segment/test004/test004_00674.csv
#   inflating: test_segment/test_segment/test004/test004_00675.csv
#   inflating: test_segment/test_segment/test004/test004_00676.csv
#   inflating: test_segment/test_segment/test004/test004_00677.csv
#   inflating: test_segment/test_segment/test004/test004_00678.csv
#   inflating: test_segment/test_segment/test004/test004_00679.csv
#   inflating: test_segment/test_segment/test004/test004_00680.csv
#   inflating: test_segment/test_segment/test004/test004_00681.csv
#   inflating: test_segment/test_segment/test004/test004_00682.csv
#   inflating: test_segment/test_segment/test004/test004_00683.csv
#   inflating: test_segment/test_segment/test004/test004_00684.csv
#   inflating: test_segment/test_segment/test004/test004_00685.csv
#   inflating: test_segment/test_segment/test004/test004_00686.csv
#   inflating: test_segment/test_segment/test004/test004_00687.csv
#   inflating: test_segment/test_segment/test004/test004_00688.csv
#   inflating: test_segment/test_segment/test004/test004_00689.csv
#   inflating: test_segment/test_segment/test004/test004_00690.csv
#   inflating: test_segment/test_segment/test004/test004_00691.csv
#   inflating: test_segment/test_segment/test004/test004_00692.csv
#   inflating: test_segment/test_segment/test004/test004_00693.csv
#   inflating: test_segment/test_segment/test004/test004_00694.csv
#   inflating: test_segment/test_segment/test004/test004_00695.csv
#   inflating: test_segment/test_segment/test004/test004_00696.csv
#   inflating: test_segment/test_segment/test004/test004_00697.csv
#   inflating: test_segment/test_segment/test004/test004_00698.csv
#   inflating: test_segment/test_segment/test004/test004_00699.csv
#   inflating: test_segment/test_segment/test004/test004_00700.csv
#   inflating: test_segment/test_segment/test005/test005_00000.csv
#   inflating: test_segment/test_segment/test005/test005_00001.csv
#   inflating: test_segment/test_segment/test005/test005_00002.csv
#   inflating: test_segment/test_segment/test005/test005_00003.csv
#   inflating: test_segment/test_segment/test005/test005_00004.csv
# ...
#   inflating: test_segment/test_segment/test010/test010_00512.csv
#   inflating: test_segment/test_segment/test010/test010_00513.csv
#   inflating: test_segment/test_segment/test010/test010_00514.csv
#   inflating: test_segment/test_segment/test010/test010_00515.csv
#   inflating: test_segment/test_segment/test010/test010_00516.csv
#   inflating: test_segment/test_segment/test010/test010_00517.csv
#   inflating: test_segment/test_segment/test010/test010_00518.csv
#   inflating: test_segment/test_segment/test010/test010_00519.csv
#   inflating: test_segment/test_segment/test010/test010_00520.csv
#   inflating: test_segment/test_segment/test010/test010_00521.csv
#   inflating: test_segment/test_segment/test010/test010_00522.csv
#   inflating: test_segment/test_segment/test010/test010_00523.csv
#   inflating: test_segment/test_segment/test010/test010_00524.csv
#   inflating: test_segment/test_segment/test010/test010_00525.csv
#   inflating: test_segment/test_segment/test010/test010_00526.csv
#   inflating: test_segment/test_segment/test010/test010_00527.csv
#   inflating: test_segment/test_segment/test010/test010_00528.csv
#   inflating: test_segment/test_segment/test010/test010_00529.csv
#   inflating: test_segment/test_segment/test010/test010_00530.csv
#   inflating: test_segment/test_segment/test010/test010_00531.csv
#   inflating: test_segment/test_segment/test010/test010_00532.csv
#   inflating: test_segment/test_segment/test010/test010_00533.csv
#   inflating: test_segment/test_segment/test010/test010_00534.csv
#   inflating: test_segment/test_segment/test010/test010_00535.csv
#   inflating: test_segment/test_segment/test010/test010_00536.csv
#   inflating: test_segment/test_segment/test010/test010_00537.csv
#   inflating: test_segment/test_segment/test010/test010_00538.csv
#   inflating: test_segment/test_segment/test010/test010_00539.csv
#   inflating: test_segment/test_segment/test010/test010_00540.csv
#   inflating: test_segment/test_segment/test010/test010_00541.csv
#   inflating: test_segment/test_segment/test010/test010_00542.csv
#   inflating: test_segment/test_segment/test010/test010_00543.csv
#   inflating: test_segment/test_segment/test010/test010_00544.csv
#   inflating: test_segment/test_segment/test010/test010_00545.csv
#   inflating: test_segment/test_segment/test010/test010_00546.csv
#   inflating: test_segment/test_segment/test010/test010_00547.csv
#   inflating: test_segment/test_segment/test010/test010_00548.csv
#   inflating: test_segment/test_segment/test010/test010_00549.csv
#   inflating: test_segment/test_segment/test010/test010_00550.csv
#   inflating: test_segment/test_segment/test010/test010_00551.csv
#   inflating: test_segment/test_segment/test010/test010_00552.csv
#   inflating: test_segment/test_segment/test010/test010_00553.csv
#   inflating: test_segment/test_segment/test010/test010_00554.csv
#   inflating: test_segment/test_segment/test010/test010_00555.csv
#   inflating: test_segment/test_segment/test010/test010_00556.csv
#   inflating: test_segment/test_segment/test010/test010_00557.csv
#   inflating: test_segment/test_segment/test010/test010_00558.csv
#   inflating: test_segment/test_segment/test010/test010_00559.csv
#   inflating: test_segment/test_segment/test010/test010_00560.csv
#   inflating: test_segment/test_segment/test010/test010_00561.csv
#   inflating: test_segment/test_segment/test010/test010_00562.csv
#   inflating: test_segment/test_segment/test010/test010_00563.csv
#   inflating: test_segment/test_segment/test010/test010_00564.csv
#   inflating: test_segment/test_segment/test010/test010_00565.csv
#   inflating: test_segment/test_segment/test010/test010_00566.csv
#   inflating: test_segment/test_segment/test010/test010_00567.csv
#   inflating: test_segment/test_segment/test010/test010_00568.csv
#   inflating: test_segment/test_segment/test010/test010_00569.csv
#   inflating: test_segment/test_segment/test010/test010_00570.csv
#   inflating: test_segment/test_segment/test010/test010_00571.csv
#   inflating: test_segment/test_segment/test010/test010_00572.csv
#   inflating: test_segment/test_segment/test010/test010_00573.csv
#   inflating: test_segment/test_segment/test010/test010_00574.csv
#   inflating: test_segment/test_segment/test010/test010_00575.csv
#   inflating: test_segment/test_segment/test010/test010_00576.csv
#   inflating: test_segment/test_segment/test010/test010_00577.csv
#   inflating: test_segment/test_segment/test010/test010_00578.csv
#   inflating: test_segment/test_segment/test010/test010_00579.csv
#   inflating: test_segment/test_segment/test010/test010_00580.csv
#   inflating: test_segment/test_segment/test010/test010_00581.csv
#   inflating: test_segment/test_segment/test010/test010_00582.csv
#   inflating: test_segment/test_segment/test010/test010_00583.csv
#   inflating: test_segment/test_segment/test010/test010_00584.csv
#   inflating: test_segment/test_segment/test010/test010_00585.csv
#   inflating: test_segment/test_segment/test010/test010_00586.csv
#   inflating: test_segment/test_segment/test010/test010_00587.csv
#   inflating: test_segment/test_segment/test010/test010_00588.csv
#   inflating: test_segment/test_segment/test010/test010_00589.csv
#   inflating: test_segment/test_segment/test010/test010_00590.csv
#   inflating: test_segment/test_segment/test010/test010_00591.csv
#   inflating: test_segment/test_segment/test010/test010_00592.csv
#   inflating: test_segment/test_segment/test010/test010_00593.csv
#   inflating: test_segment/test_segment/test010/test010_00594.csv
#   inflating: test_segment/test_segment/test010/test010_00595.csv
#   inflating: test_segment/test_segment/test010/test010_00596.csv
#   inflating: test_segment/test_segment/test010/test010_00597.csv
#   inflating: test_segment/test_segment/test010/test010_00598.csv
#   inflating: test_segment/test_segment/test010/test010_00599.csv
#   inflating: test_segment/test_segment/test010/test010_00600.csv
#   inflating: test_segment/test_segment/test010/test010_00601.csv
#   inflating: test_segment/test_segment/test010/test010_00602.csv
#   inflating: test_segment/test_segment/test010/test010_00603.csv
#   inflating: test_segment/test_segment/test010/test010_00604.csv
#   inflating: test_segment/test_segment/test010/test010_00605.csv
#   inflating: test_segment/test_segment/test010/test010_00606.csv
#   inflating: test_segment/test_segment/test010/test010_00607.csv
#   inflating: test_segment/test_segment/test010/test010_00608.csv
#   inflating: test_segment/test_segment/test010/test010_00609.csv
#   inflating: test_segment/test_segment/test010/test010_00610.csv
#   inflating: test_segment/test_segment/test010/test010_00611.csv
#   inflating: test_segment/test_segment/test010/test010_00612.csv
#   inflating: test_segment/test_segment/test010/test010_00613.csv
#   inflating: test_segment/test_segment/test010/test010_00614.csv
#   inflating: test_segment/test_segment/test010/test010_00615.csv
#   inflating: test_segment/test_segment/test010/test010_00616.csv
#   inflating: test_segment/test_segment/test010/test010_00617.csv
#   inflating: test_segment/test_segment/test010/test010_00618.csv
#   inflating: test_segment/test_segment/test010/test010_00619.csv
#   inflating: test_segment/test_segment/test010/test010_00620.csv
#   inflating: test_segment/test_segment/test010/test010_00621.csv
#   inflating: test_segment/test_segment/test010/test010_00622.csv
#   inflating: test_segment/test_segment/test010/test010_00623.csv
#   inflating: test_segment/test_segment/test010/test010_00624.csv
#   inflating: test_segment/test_segment/test010/test010_00625.csv
#   inflating: test_segment/test_segment/test010/test010_00626.csv
#   inflating: test_segment/test_segment/test010/test010_00627.csv
#   inflating: test_segment/test_segment/test010/test010_00628.csv
#   inflating: test_segment/test_segment/test010/test010_00629.csv
#   inflating: test_segment/test_segment/test010/test010_00630.csv
#   inflating: test_segment/test_segment/test010/test010_00631.csv
#   inflating: test_segment/test_segment/test010/test010_00632.csv
#   inflating: test_segment/test_segment/test010/test010_00633.csv
#   inflating: test_segment/test_segment/test010/test010_00634.csv
#   inflating: test_segment/test_segment/test010/test010_00635.csv
#   inflating: test_segment/test_segment/test010/test010_00636.csv
#   inflating: test_segment/test_segment/test010/test010_00637.csv
#   inflating: test_segment/test_segment/test010/test010_00638.csv
#   inflating: test_segment/test_segment/test010/test010_00639.csv
#   inflating: test_segment/test_segment/test010/test010_00640.csv
#   inflating: test_segment/test_segment/test010/test010_00641.csv
#   inflating: test_segment/test_segment/test010/test010_00642.csv
#   inflating: test_segment/test_segment/test010/test010_00643.csv
#   inflating: test_segment/test_segment/test010/test010_00644.csv
#   inflating: test_segment/test_segment/test010/test010_00645.csv
#   inflating: test_segment/test_segment/test010/test010_00646.csv
#   inflating: test_segment/test_segment/test010/test010_00647.csv
#   inflating: test_segment/test_segment/test010/test010_00648.csv
#   inflating: test_segment/test_segment/test010/test010_00649.csv
#   inflating: test_segment/test_segment/test010/test010_00650.csv
#   inflating: test_segment/test_segment/test010/test010_00651.csv
#   inflating: test_segment/test_segment/test010/test010_00652.csv
#   inflating: test_segment/test_segment/test010/test010_00653.csv
#   inflating: test_segment/test_segment/test010/test010_00654.csv
#   inflating: test_segment/test_segment/test010/test010_00655.csv
#   inflating: test_segment/test_segment/test010/test010_00656.csv
#   inflating: test_segment/test_segment/test010/test010_00657.csv
#   inflating: test_segment/test_segment/test010/test010_00658.csv
#   inflating: test_segment/test_segment/test010/test010_00659.csv
#   inflating: test_segment/test_segment/test010/test010_00660.csv
#   inflating: test_segment/test_segment/test010/test010_00661.csv
#   inflating: test_segment/test_segment/test010/test010_00662.csv
#   inflating: test_segment/test_segment/test010/test010_00663.csv
#   inflating: test_segment/test_segment/test010/test010_00664.csv
#   inflating: test_segment/test_segment/test010/test010_00665.csv
#   inflating: test_segment/test_segment/test010/test010_00666.csv
#   inflating: test_segment/test_segment/test010/test010_00667.csv
#   inflating: test_segment/test_segment/test010/test010_00668.csv
#   inflating: test_segment/test_segment/test010/test010_00669.csv
#   inflating: test_segment/test_segment/test010/test010_00670.csv
#   inflating: test_segment/test_segment/test010/test010_00671.csv
#   inflating: test_segment/test_segment/test010/test010_00672.csv
#   inflating: test_segment/test_segment/test010/test010_00673.csv
#   inflating: test_segment/test_segment/test010/test010_00674.csv
#   inflating: test_segment/test_segment/test010/test010_00675.csv
#   inflating: test_segment/test_segment/test010/test010_00676.csv
#   inflating: test_segment/test_segment/test010/test010_00677.csv
#   inflating: test_segment/test_segment/test010/test010_00678.csv
#   inflating: test_segment/test_segment/test010/test010_00679.csv
#   inflating: test_segment/test_segment/test010/test010_00680.csv
#   inflating: test_segment/test_segment/test010/test010_00681.csv
#   inflating: test_segment/test_segment/test010/test010_00682.csv
#   inflating: test_segment/test_segment/test010/test010_00683.csv
#   inflating: test_segment/test_segment/test010/test010_00684.csv
#   inflating: test_segment/test_segment/test010/test010_00685.csv
#   inflating: test_segment/test_segment/test010/test010_00686.csv
#   inflating: test_segment/test_segment/test010/test010_00687.csv
#   inflating: test_segment/test_segment/test010/test010_00688.csv
#   inflating: test_segment/test_segment/test010/test010_00689.csv
#   inflating: test_segment/test_segment/test010/test010_00690.csv
#   inflating: test_segment/test_segment/test010/test010_00691.csv
#   inflating: test_segment/test_segment/test010/test010_00692.csv
#   inflating: test_segment/test_segment/test010/test010_00693.csv
#   inflating: test_segment/test_segment/test010/test010_00694.csv
#   inflating: test_segment/test_segment/test010/test010_00695.csv
#   inflating: test_segment/test_segment/test010/test010_00696.csv
#   inflating: test_segment/test_segment/test010/test010_00697.csv
#   inflating: test_segment/test_segment/test010/test010_00698.csv
#   inflating: test_segment/test_segment/test010/test010_00699.csv
#   inflating: test_segment/test_segment/test010/test010_00700.csv
#   inflating: train/train/train001.csv
#   inflating: train/train/train002.csv
#   inflating: train/train/train003.csv
#   inflating: train/train/train004.csv
#   inflating: train/train/train005.csv
#   inflating: train/train/train006.csv
#   inflating: train/train/train007.csv
#   inflating: train/train/train008.csv
#   inflating: train/train/train009.csv
#   inflating: train/train/train010.csv
#   inflating: train/train/train011.csv
#   inflating: train/train/train012.csv
#   inflating: train/train/train013.csv
#   inflating: train/train/train014.csv
#   inflating: train/train/train015.csv
#   inflating: train/train/train016.csv
#   inflating: train/train/train017.csv
#   inflating: train/train/train018.csv
#   inflating: train/train/train019.csv
#   inflating: train/train/train020.csv
#   inflating: train/train/train021.csv
#   inflating: train/train/train022.csv
#   inflating: train/train/train023.csv
#   inflating: train/train/train024.csv
#   inflating: train/train/train025.csv
#   inflating: train/train/train026.csv
#   inflating: train/train/train027.csv
#   inflating: train/train/train028.csv
#   inflating: train/train/train029.csv
#   inflating: train/train/train030.csv
#   inflating: train/train/train031.csv
#   inflating: train/train/train032.csv
#   inflating: train/train/train033.csv
#   inflating: train/train/train034.csv
#   inflating: train/train/train035.csv
#   inflating: train/train/train036.csv
#   inflating: train/train/train037.csv
#   inflating: train/train/train038.csv
#   inflating: train/train/train039.csv
#   inflating: train/train/train040.csv
#   inflating: train/train/train041.csv
#   inflating: train/train/train042.csv
#   inflating: train/train/train043.csv
#   inflating: train/train/train044.csv
#   inflating: train/train/train045.csv
#   inflating: train/train/train046.csv
#   inflating: train/train/train047.csv
#   inflating: train/train/train048.csv
#   inflating: train/train/train049.csv
#   inflating: train/train/train050.csv
#   inflating: train/train/train051.csv
#   inflating: train/train/train052.csv
#   inflating: train/train/train053.csv
#   inflating: train/train/train054.csv
#   inflating: train/train/train055.csv
#   inflating: train/train/train056.csv
#   inflating: train/train/train057.csv
#   inflating: train/train/train058.csv
#   inflating: train/train/train059.csv
#   inflating: train/train/train060.csv
#   inflating: train/train/train061.csv
#   inflating: train/train/train062.csv
#   inflating: train/train/train063.csv
#   inflating: train/train/train064.csv
#   inflating: train/train/train065.csv
#   inflating: train/train/train066.csv
#   inflating: train/train/train067.csv
#   inflating: train/train/train068.csv
#   inflating: train/train/train069.csv
#   inflating: train/train/train070.csv
#   inflating: train/train/train071.csv
#   inflating: train/train/train072.csv
#   inflating: train/train/train073.csv
#   inflating: train/train/train074.csv
#   inflating: train/train/train075.csv
#   inflating: train/train/train076.csv
#   inflating: train/train/train077.csv
#   inflating: train/train/train078.csv
#   inflating: train/train/train079.csv
#   inflating: train/train/train080.csv
#   inflating: train/train/train081.csv
#   inflating: train/train/train082.csv
#   inflating: train/train/train083.csv

# %%
import pandas as pd
import glob

file_list = glob.glob("/content/train/train/*.csv")
all_data = []
for file in file_list:
    try:
        df = pd.read_csv(file)

        all_data.append(df)

    except Exception as e:
        print(f"⚠️ อ่านไฟล์ {file} ไม่ได้: {e}")

combined_df = pd.concat(all_data, ignore_index=True)
combined_df
# Out:
# 📊 ข้อมูลรวมทั้งหมดมีขนาด: (31907040, 9)
#                 BVP      ACC_X      ACC_Y      ACC_Z       TEMP       EDA  \
# 0          2.418650 -14.828296  30.645146  53.385008  33.264834  0.278546
# 1          1.526770 -14.828296  30.645146  52.653695  33.264823  0.278577
# 2          2.428460 -14.828296  30.645146  53.279565  33.264756  0.278481
# 3          0.924600 -14.828296  30.645146  53.049354  33.264908  0.278677
# 4          0.188797 -14.828296  30.645146  53.178063  33.264693  0.277723
# ...             ...        ...        ...        ...        ...       ...
# 31907035   7.471146  -7.955707  37.565038  50.902734  35.143026  0.106351
# 31907036  -0.556221  -7.814153  37.564986  51.253416  35.143145  0.106385
# 31907037  -7.292864  -8.163047  37.565050  50.536319  35.142969  0.106378
# 31907038 -15.821066  -8.264469  37.564994  50.477461  35.143138  0.106369
# 31907039 -24.164324  -7.828593  37.565028  50.845864  35.143022  0.106392
#
#                  HR       IBI Sleep_Stage
# 0         88.030792  0.787580           W
# 1         88.030735  0.788122           W
# 2         88.030291  0.787050           W
# 3         88.031277  0.788368           W
# 4         88.029887  0.786861           W
# ...             ...       ...         ...
# 31907035  56.713585  0.942194           W
# 31907036  56.712603  0.942242           W
# 31907037  56.714083  0.942190           W
# 31907038  56.712645  0.942230           W
# 31907039  56.713642  0.942210           W
#
# [31907040 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from scipy.fftpack import fft

segment_size = 480

def extract_features(segment):
    features = {}

    # ดึงค่าทางสถิติจากแต่ละเซ็นเซอร์
    for col in ["BVP", "ACC_X", "ACC_Y", "ACC_Z", "TEMP", "EDA", "HR", "IBI"]:
        values = segment[col].values
        features[f"mean_{col}"] = np.mean(values)
        features[f"std_{col}"] = np.std(values)
        features[f"max_{col}"] = np.max(values)
        features[f"min_{col}"] = np.min(values)
        features[f"median_{col}"] = np.median(values)
        features[f"skew_{col}"] = skew(values)
        features[f"kurtosis_{col}"] = kurtosis(values)

    # คำนวณ SMA (Signal Magnitude Area) สำหรับการเคลื่อนไหว
    features["sma_acc"] = np.sum(np.abs(segment["ACC_X"]) + np.abs(segment["ACC_Y"]) + np.abs(segment["ACC_Z"]))

    # คำนวณพลังงานของสัญญาณ (Energy)
    for col in ["BVP", "EDA", "HR"]:
        features[f"energy_{col}"] = np.sum(np.square(values)) / len(values)


    fft_values = np.abs(fft(segment["HR"].values))
    features["fft_peak_hr"] = np.argmax(fft_values)


    features["Sleep_Stage"] = segment["Sleep_Stage"].values[0]

    return features


feature_list = []
for i in range(0, len(combined_df), segment_size):
    segment = combined_df.iloc[i:i+segment_size]
    if len(segment) == segment_size:
        feature_list.append(extract_features(segment))


feature_df = pd.DataFrame(feature_list)
# Out:
# <ipython-input-4-de327cd2d553>:19: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-4-de327cd2d553>:20: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import LabelEncoder

# แยก Features และ Labels
X = feature_df.drop(columns=["Sleep_Stage"])
# แปลง Sleep_Stage จากตัวอักษรเป็นตัวเลข
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(feature_df["Sleep_Stage"])

# ดูการแมปค่า Label
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# ใช้ Random Forest เพื่อเลือก Features ที่สำคัญ
selector = SelectFromModel(RandomForestClassifier(n_estimators=100, random_state=42))
selector.fit(X, y)

# เลือกเฉพาะ Features ที่สำคัญ
X_selected = X.loc[:, selector.get_support()]

# %%
X_selected
# Out:
#          std_BVP    max_BVP    min_BVP  kurtosis_BVP  mean_ACC_X  \
# 0       3.380333   6.721362 -10.770070     -0.493754  -14.355264
# 1       3.935875  31.704457 -14.867657     13.311258   -7.918330
# 2       3.048122   5.466780  -6.612507     -0.977987   -7.908425
# 3       3.019995   7.930728  -6.514300     -0.886724   -7.976691
# 4       3.080849   8.962223 -11.341948     -0.315907   -9.390520
# ...          ...        ...        ...           ...         ...
# 66468  22.398665  40.263323 -42.427387     -1.208328   -9.843343
# 66469  21.826509  42.411884 -46.638104     -1.109979   -9.637162
# 66470  22.656818  43.579126 -44.022952     -1.091839   -9.811608
# 66471  22.659089  38.140872 -43.031622     -1.189028   -7.978950
# 66472  21.538408  37.692507 -41.618756     -1.157266   -7.928965
#
#           std_ACC_X  max_ACC_X  min_ACC_X  median_ACC_X  mean_ACC_Y  ...  \
# 0      2.244520e+00  -0.757936 -19.726688    -14.828335   30.464842  ...
# 1      7.591805e-02  -7.691100  -8.768982     -7.908425   30.633918  ...
# 2      9.196477e-10  -7.908425  -7.908425     -7.908425   30.645146  ...
# 3      2.974962e-01  -6.830426  -9.157902     -7.908425   30.666774  ...
# 4      4.679507e-01  -5.900315 -10.680165     -9.463630   30.620402  ...
# ...             ...        ...        ...           ...         ...  ...
# 66468  1.449272e-01  -8.811666 -10.077662     -9.885198   37.415862  ...
# 66469  4.684972e-01  -7.839029 -10.907642     -9.883842   37.409413  ...
# 66470  2.570399e-01  -8.779109 -11.453235     -9.885511   37.121866  ...
# 66471  3.906126e-01  -6.726895 -10.024153     -7.908425   37.578745  ...
# 66472  9.086467e-02  -7.753670  -8.666455     -7.908426   37.569137  ...
#
#        mean_TEMP   max_TEMP   min_TEMP  median_TEMP  mean_EDA   max_EDA  \
# 0      33.251327  33.275627  33.222905    33.252814  0.278338  0.281467
# 1      33.247007  33.268529  33.223404    33.245042  0.278222  0.281402
# 2      33.250310  33.266686  33.223404    33.245071  0.278463  0.280200
# 3      33.248338  33.267122  33.221574    33.245045  0.279496  0.282604
# 4      33.250956  33.268529  33.222921    33.245079  0.279994  0.282696
# ...          ...        ...        ...          ...       ...       ...
# 66468  35.021138  35.046070  34.981172    35.024394  0.109874  0.111710
# 66469  35.059321  35.085615  35.036469    35.063977  0.109759  0.112879
# 66470  35.097558  35.147714  35.040476    35.093589  0.107185  0.109271
# 66471  35.142043  35.166545  35.088962    35.143062  0.107372  0.109168
# 66472  35.168780  35.186327  35.140653    35.163070  0.107268  0.109185
#
#         min_EDA  median_EDA    std_HR       sma_acc
# 0      0.275844    0.278518  0.308713  47081.203465
# 1      0.275781    0.278512  0.670249  44602.966736
# 2      0.274561    0.278546  0.622197  44603.515631
# 3      0.276923    0.279736  0.281799  44634.303798
# 4      0.276998    0.279834  0.830735  45270.894875
# ...         ...         ...       ...           ...
# 66468  0.106086    0.110145  1.775145  46957.876672
# 66469  0.106055    0.110080  0.769390  46869.171661
# 66470  0.104824    0.107511  0.730192  46878.500774
# 66471  0.104861    0.107626  1.167451  46125.325063
# 66472  0.104887    0.107535  0.648440  46083.330189
#
# [66473 rows x 29 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
import xgboost as xgb


X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# โมเดลที่ 1: Random Forest
rf_model = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

# โมเดลที่ 2: XGBoost
xgb_model = xgb.XGBClassifier(n_estimators=200, max_depth=10, learning_rate=0.05, random_state=42)
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)


rf_acc = accuracy_score(y_test, rf_pred)
xgb_acc = accuracy_score(y_test, xgb_pred)
rf_f1 = f1_score(y_test, rf_pred, average='weighted')
xgb_f1 = f1_score(y_test, xgb_pred, average='weighted')

print(f"🎯 Random Forest: Accuracy = {rf_acc:.4f}, F1-score = {rf_f1:.4f}")
print(f"🚀 XGBoost: Accuracy = {xgb_acc:.4f}, F1-score = {xgb_f1:.4f}")
# Out:
# 🎯 Random Forest: Accuracy = 0.7447, F1-score = 0.6968
# 🚀 XGBoost: Accuracy = 0.8618, F1-score = 0.8576

# %%
import pandas as pd
import glob
import os
import numpy as np
from scipy.stats import skew, kurtosis
from scipy.fftpack import fft

# กำหนด path หลักที่เก็บไฟล์ทดสอบ
test_path = "/content/test_segment/test_segment/"

# ค้นหาไฟล์ CSV ทุกไฟล์ภายใต้ test_segment (รวมทุกโฟลเดอร์ย่อย)
test_file_list = glob.glob(os.path.join(test_path, "**/*.csv"), recursive=True)

# ลิสต์เก็บ DataFrame ของแต่ละไฟล์ที่ผ่าน Feature Extraction แล้ว
feature_data = []

# ฟังก์ชัน Feature Extraction จาก Segment
def extract_features(segment, subject_id):
    features = {}

    # ดึงค่าทางสถิติจากแต่ละเซ็นเซอร์
    for col in ["BVP", "ACC_X", "ACC_Y", "ACC_Z", "TEMP", "EDA", "HR", "IBI"]:
        values = segment[col].values
        features[f"mean_{col}"] = np.mean(values)
        features[f"std_{col}"] = np.std(values)
        features[f"max_{col}"] = np.max(values)
        features[f"min_{col}"] = np.min(values)
        features[f"median_{col}"] = np.median(values)
        features[f"skew_{col}"] = skew(values)
        features[f"kurtosis_{col}"] = kurtosis(values)

    # คำนวณ SMA (Signal Magnitude Area) สำหรับการเคลื่อนไหว
    features["sma_acc"] = np.sum(np.abs(segment["ACC_X"]) + np.abs(segment["ACC_Y"]) + np.abs(segment["ACC_Z"]))

    # คำนวณพลังงานของสัญญาณ (Energy)
    for col in ["BVP", "EDA", "HR"]:
        features[f"energy_{col}"] = np.sum(np.square(values)) / len(values)

    # คำนวณ FFT (Peak Frequency)
    fft_values = np.abs(fft(segment["HR"].values))
    features["fft_peak_hr"] = np.argmax(fft_values)  # จุดสูงสุดของสัญญาณ HR

    # ระบุ Segment_ID
    features["Segment_ID"] = subject_id

    return features


segment_size = 480

for file in test_file_list:
    try:
        df = pd.read_csv(file)


        subject_id = os.path.basename(file).replace(".csv", "")


        for i in range(0, len(df), segment_size):
            segment = df.iloc[i:i+segment_size]
            if len(segment) == segment_size:
                feature_data.append(extract_features(segment, subject_id))

    except Exception as e:
        print(f"⚠️ อ่านไฟล์ {file} ไม่ได้: {e}")


test_feature_df = pd.DataFrame(feature_data)

test_feature_df
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# ...
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
# <ipython-input-23-abb2bfcd9553>:29: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"skew_{col}"] = skew(values)
# <ipython-input-23-abb2bfcd9553>:30: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   features[f"kurtosis_{col}"] = kurtosis(values)
#       mean_BVP    std_BVP     max_BVP     min_BVP  median_BVP  skew_BVP  \
# 0    -0.660568  49.584365   78.714863  -95.118212    7.442161 -0.278681
# 1    -0.282654  45.027972  100.510150 -102.085505    8.021984 -0.255636
# 2     1.254593  97.369294  154.554149 -194.467723   20.694666 -0.333876
# 3     0.063165  84.857607  148.536971 -195.968385   12.190177 -0.301702
# 4    -0.888846  62.167925  103.825793 -117.624006    6.300406 -0.152799
# ...        ...        ...         ...         ...         ...       ...
# 7005 -0.021821   7.182946   14.357846  -14.613163    0.750254 -0.091152
# 7006  0.047897   2.972990    7.344961   -7.039800    0.299656 -0.109628
# 7007 -0.002356   4.867600    8.980665  -11.299846    0.568210 -0.254652
# 7008  0.063286   7.163264   14.056709  -13.331737    0.772995 -0.063407
# 7009 -0.014379   6.372291   11.824513  -11.971469    0.362871 -0.123859
#
#       kurtosis_BVP  mean_ACC_X  std_ACC_X  max_ACC_X  ...   min_IBI  \
# 0        -1.117319  -45.443401   0.114677 -44.715476  ...  0.892994
# 1        -1.079404  -63.262251   0.295319 -60.465970  ...  0.877557
# 2        -1.127100  -57.339169   0.035139 -57.228456  ...  0.894521
# 3        -1.127790  -57.410159   0.247891 -56.192492  ...  0.922523
# 4        -1.201254   42.536589   0.109506  43.270503  ...  0.938563
# ...            ...         ...        ...        ...  ...       ...
# 7005     -1.091981   34.084671   0.437056  35.517934  ...  0.669161
# 7006     -0.759120  -46.286700   0.257063 -45.268635  ...  0.733130
# 7007     -1.092727   22.318288   0.506093  23.605235  ...  0.750933
# 7008     -1.248231   44.474975   0.062850  44.575000  ...  0.830301
# 7009     -1.210671  -22.727394   0.084694 -21.802697  ...  0.755542
#
#       median_IBI  skew_IBI  kurtosis_IBI       sma_acc  energy_BVP  \
# 0       0.941676 -0.080938     -0.708926  49825.810290    0.881601
# 1       0.911473  0.080295     -1.185611  36464.000393    0.853562
# 2       0.973573 -0.411592     -0.739105  44557.022975    0.945593
# 3       1.003771 -0.285750     -0.529898  44464.659667    0.996818
# 4       0.972658 -0.078236     -1.007763  49364.876491    0.936236
# ...          ...       ...           ...           ...         ...
# 7005    0.801200 -0.614056      2.339741  52151.281852    0.628774
# 7006    0.818571  0.031073     -1.292938  43685.266796    0.701736
# 7007    0.802522  2.092234      7.324980  51063.000753    0.644067
# 7008    0.895751 -0.279648     -0.931523  49221.205859    0.797515
# 7009    0.894281 -0.606244      6.913305  50950.887948    0.787217
#
#       energy_EDA  energy_HR  fft_peak_hr     Segment_ID
# 0       0.881601   0.881601            0  test006_00139
# 1       0.853562   0.853562            0  test006_00060
# 2       0.945593   0.945593            0  test006_00370
# 3       0.996818   0.996818            0  test006_00391
# 4       0.936236   0.936236            0  test006_00580
# ...          ...        ...          ...            ...
# 7005    0.628774   0.628774            0  test004_00095
# 7006    0.701736   0.701736            0  test004_00020
# 7007    0.644067   0.644067            0  test004_00064
# 7008    0.797515   0.797515            0  test004_00622
# 7009    0.787217   0.787217            0  test004_00457
#
# [7010 rows x 62 columns]

# %%
test_feature_df.columns
# Out:
# Index(['mean_BVP', 'std_BVP', 'max_BVP', 'min_BVP', 'median_BVP', 'skew_BVP',
#        'kurtosis_BVP', 'mean_ACC_X', 'std_ACC_X', 'max_ACC_X', 'min_ACC_X',
#        'median_ACC_X', 'skew_ACC_X', 'kurtosis_ACC_X', 'mean_ACC_Y',
#        'std_ACC_Y', 'max_ACC_Y', 'min_ACC_Y', 'median_ACC_Y', 'skew_ACC_Y',
#        'kurtosis_ACC_Y', 'mean_ACC_Z', 'std_ACC_Z', 'max_ACC_Z', 'min_ACC_Z',
#        'median_ACC_Z', 'skew_ACC_Z', 'kurtosis_ACC_Z', 'mean_TEMP', 'std_TEMP',
#        'max_TEMP', 'min_TEMP', 'median_TEMP', 'skew_TEMP', 'kurtosis_TEMP',
#        'mean_EDA', 'std_EDA', 'max_EDA', 'min_EDA', 'median_EDA', 'skew_EDA',
#        'kurtosis_EDA', 'mean_HR', 'std_HR', 'max_HR', 'min_HR', 'median_HR',
#        'skew_HR', 'kurtosis_HR', 'mean_IBI', 'std_IBI', 'max_IBI', 'min_IBI',
#        'median_IBI', 'skew_IBI', 'kurtosis_IBI', 'sma_acc', 'energy_BVP',
#        'energy_EDA', 'energy_HR', 'fft_peak_hr', 'Segment_ID'],
#       dtype='object')

# %%
X_selected.columns
# Out:
# Index(['std_BVP', 'max_BVP', 'min_BVP', 'kurtosis_BVP', 'mean_ACC_X',
#        'std_ACC_X', 'max_ACC_X', 'min_ACC_X', 'median_ACC_X', 'mean_ACC_Y',
#        'std_ACC_Y', 'max_ACC_Y', 'min_ACC_Y', 'median_ACC_Y', 'mean_ACC_Z',
#        'std_ACC_Z', 'max_ACC_Z', 'min_ACC_Z', 'median_ACC_Z', 'mean_TEMP',
#        'max_TEMP', 'min_TEMP', 'median_TEMP', 'mean_EDA', 'max_EDA', 'min_EDA',
#        'median_EDA', 'std_HR', 'sma_acc'],
#       dtype='object')

# %%
selected_columns = X_selected.columns

common_columns = [col for col in selected_columns if col in test_feature_df.columns]

test_feature_df1 = test_feature_df[common_columns]
test_feature_df1.columns
# Out:
# Index(['std_BVP', 'max_BVP', 'min_BVP', 'kurtosis_BVP', 'mean_ACC_X',
#        'std_ACC_X', 'max_ACC_X', 'min_ACC_X', 'median_ACC_X', 'mean_ACC_Y',
#        'std_ACC_Y', 'max_ACC_Y', 'min_ACC_Y', 'median_ACC_Y', 'mean_ACC_Z',
#        'std_ACC_Z', 'max_ACC_Z', 'min_ACC_Z', 'median_ACC_Z', 'mean_TEMP',
#        'max_TEMP', 'min_TEMP', 'median_TEMP', 'mean_EDA', 'max_EDA', 'min_EDA',
#        'median_EDA', 'std_HR', 'sma_acc'],
#       dtype='object')

# %%
predictions = rf_model.predict(test_feature_df1)

# แปลง Label กลับจากตัวเลข → ตัวอักษร (W, N, R)
predictions = label_encoder.inverse_transform(predictions)

# %%
submission_df = pd.DataFrame({
    "id": test_feature_df["Segment_ID"],
    "labels": predictions
})
submission_df = submission_df.sort_values(by=["id"]).reset_index(drop=True)

# %%
submission_df.head()
# Out:
#               id labels
# 0  test001_00000      W
# 1  test001_00001      W
# 2  test001_00002      W
# 3  test001_00003      W
# 4  test001_00004      W

# %%
submission_df.to_csv("submission_rf.csv", index=False)
